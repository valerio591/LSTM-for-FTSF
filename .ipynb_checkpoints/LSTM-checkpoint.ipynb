# %%
import pandas as pd
import numpy as np
import datetime as datetime
import matplotlib.pyplot as plt
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from package import euklid as eu

# %%
path ="../data.csv"

# %%
yahoo_df = pd.read_csv('data.csv')

# %%
# Add indicators
yahoo_df['vwap'] = eu.vwap(yahoo_df['Close'], yahoo_df['Volume'])
yahoo_df['SO'] = eu.Stochastic_Oscillator(yahoo_df['Close'])
yahoo_df['RSI'] = eu.rsi(yahoo_df['Close'],14)
eu.macd(yahoo_df,yahoo_df['Close'])

# Select valid data
yahoo_df = yahoo_df[35:]

# %% [markdown]
# # Normalize

# %%
days_ahead = 1
differenced = yahoo_df['Close'] - yahoo_df['Close'].shift(days_ahead)[days_ahead:]
previous_differenced = differenced.shift(1)
yahoo_df["Previous_differenced"] = previous_differenced
yahoo_df["Differenced"] = differenced
yahoo_df = yahoo_df[days_ahead+1:]
yahoo_df.head()
# Out:
# <ipython-input-5-a402d1ae899a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yahoo_df["Previous_differenced"] = previous_differenced
# <ipython-input-5-a402d1ae899a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yahoo_df["Differenced"] = differenced
#           Date  Adj Close      Close        High        Low       Open  \
# 37  2000-12-05  58.167889  98.828873  100.143402  95.243790  96.020554
# 38  2000-12-06  54.440067  92.495216   97.335083  90.642921  97.275337
# 39  2000-12-07  52.400330  89.029640   91.718452  89.029640  90.881927
# 40  2000-12-08  54.580730  92.734222   94.646271  91.539200  93.690247
# 41  2000-12-11  53.455372  90.822182   93.929253  89.627151  92.256210
#
#         Volume       vwap          SO        RSI       KAMA         T3  \
# 37   8163193.0  94.594211  100.000000  63.284273  96.710635  94.013318
# 38  10561357.0  94.339957   32.911351  54.458065  96.663721  94.007013
# 39   8286412.0  93.881788    0.000000  50.341906  96.575398  93.828420
# 40   6423068.0  93.809730   37.804820  54.298214  96.538531  93.604554
# 41   6470138.0  93.337622   18.292672  52.006912  96.506628  93.322263
#
#            OBV       ATR  MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9  \
# 37    857199.0  4.287902      0.031127       0.071222      -0.040095
# 38  -9704158.0  4.566334     -0.128677      -0.070865      -0.057811
# 39 -17990570.0  4.487708     -0.528869      -0.376846      -0.152023
# 40 -11567502.0  4.568346     -0.540861      -0.311071      -0.229791
# 41 -18037640.0  4.549328     -0.696620      -0.373464      -0.323157
#
#     Previous_differenced  Differenced
# 37              2.629066     4.780113
# 38              4.780113    -6.333656
# 39             -6.333656    -3.465576
# 40             -3.465576     3.704582
# 41              3.704582    -1.912041

# %%
# Try to make predictions on up or down
# def up_down(price):
#     up_down = [np.nan]
#     for i in range(1,len(price)):
#         if price[i] > price[i-1]:
#             up_down.append(1)
#         else:
#             up_down.append(0)
#     return up_down
# yahoo_df['up_down'] = up_down(list(yahoo_df['Close']))
# yahoo_df

# %%
# price = yahoo_df['Differenced'] 
# price.plot()

# %%
#yahoo_df = yahoo_df.iloc[days_ahead:,:]
yahoo_df = yahoo_df.drop(columns = ['Volume', 'vwap','KAMA','OBV','T3'])
close = yahoo_df['Close']
yahoo_df = yahoo_df.iloc[:,6:-1].shift(-1)
yahoo_df = yahoo_df.iloc[:-1,:]

# %%
yahoo_df.values
# Out:
# array([[ 3.29113515e+01,  5.44580651e+01,  4.56633404e+00, ...,
#         -7.08653886e-02, -5.78113497e-02,  4.78011322e+00],
#        [ 0.00000000e+00,  5.03419056e+01,  4.48770847e+00, ...,
#         -3.76846323e-01, -1.52022930e-01, -6.33365631e+00],
#        [ 3.78048201e+01,  5.42982143e+01,  4.56834577e+00, ...,
#         -3.11070592e-01, -2.29790578e-01, -3.46557617e+00],
#        ...,
#        [ 1.00000000e+02,  6.14999210e+01,  2.82201368e+00, ...,
#          1.71322504e-01,  1.62275499e+00, -2.20001221e-01],
#        [ 5.23969265e+01,  4.93621184e+01,  2.95044093e+00, ...,
#         -1.24491595e-01,  1.59163209e+00,  7.69989014e-01],
#        [ 4.31438258e+01,  4.74132575e+01,  2.90612385e+00, ...,
#         -3.70855470e-01,  1.49891822e+00, -4.26998901e+00]])

# %%
# convert series to supervised learning
values = yahoo_df.values
# ensure all data is float
values = values.astype('float32')
# normalize features
values
# Out:
# array([[ 3.29113503e+01,  5.44580650e+01,  4.56633425e+00, ...,
#         -7.08653852e-02, -5.78113496e-02,  4.78011322e+00],
#        [ 0.00000000e+00,  5.03419075e+01,  4.48770857e+00, ...,
#         -3.76846313e-01, -1.52022928e-01, -6.33365631e+00],
#        [ 3.78048210e+01,  5.42982140e+01,  4.56834555e+00, ...,
#         -3.11070591e-01, -2.29790583e-01, -3.46557617e+00],
#        ...,
#        [ 1.00000000e+02,  6.14999199e+01,  2.82201362e+00, ...,
#          1.71322510e-01,  1.62275493e+00, -2.20001221e-01],
#        [ 5.23969269e+01,  4.93621178e+01,  2.95044088e+00, ...,
#         -1.24491595e-01,  1.59163213e+00,  7.69989014e-01],
#        [ 4.31438255e+01,  4.74132576e+01,  2.90612388e+00, ...,
#         -3.70855480e-01,  1.49891818e+00, -4.26998901e+00]], dtype=float32)

# %% [markdown]
# # Train, test, val

# %%
# split into train and test sets
n_train_days = int(round(yahoo_df.shape[0]*0.8))

# %%
train = values[:n_train_days, :]
test = values[n_train_days:, :]
close_train = list(close)[:n_train_days]
close_test = list(close)[n_train_days:]

# %%
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (4264, 1, 6) (4264,) (1066, 1, 6) (1066,)

# %% [markdown]
# # LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.layers import LSTM
from keras.callbacks import EarlyStopping
from keras import optimizers
import tensorflow as tf

# %%
# Set early stopping monitor so the model stops training when it won't improve anymore
esm = EarlyStopping(monitor = 'loss', patience = 7)

# Set the optimizer
adam = tf.optimizers.Adam(learning_rate = 0.0001)

# %%
# design network
model = Sequential()
model.add(LSTM(75, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer=adam)
# fit network
history = model.fit(train_X, train_y, epochs=500, batch_size=100, verbose=2, shuffle=False,  callbacks = [esm])
# plot history
plt.plot(history.history['loss'], label='train')
#plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/500
# 43/43 - 1s - loss: 1.2823 - 1s/epoch - 31ms/step
# Epoch 2/500
# 43/43 - 0s - loss: 1.2370 - 66ms/epoch - 2ms/step
# Epoch 3/500
# 43/43 - 0s - loss: 1.2019 - 77ms/epoch - 2ms/step
# Epoch 4/500
# 43/43 - 0s - loss: 1.1768 - 88ms/epoch - 2ms/step
# Epoch 5/500
# 43/43 - 0s - loss: 1.1606 - 75ms/epoch - 2ms/step
# Epoch 6/500
# 43/43 - 0s - loss: 1.1514 - 71ms/epoch - 2ms/step
# Epoch 7/500
# 43/43 - 0s - loss: 1.1460 - 68ms/epoch - 2ms/step
# Epoch 8/500
# 43/43 - 0s - loss: 1.1426 - 60ms/epoch - 1ms/step
# Epoch 9/500
# 43/43 - 0s - loss: 1.1404 - 57ms/epoch - 1ms/step
# Epoch 10/500
# 43/43 - 0s - loss: 1.1385 - 63ms/epoch - 1ms/step
# Epoch 11/500
# 43/43 - 0s - loss: 1.1372 - 62ms/epoch - 1ms/step
# Epoch 12/500
# 43/43 - 0s - loss: 1.1361 - 64ms/epoch - 1ms/step
# Epoch 13/500
# 43/43 - 0s - loss: 1.1354 - 74ms/epoch - 2ms/step
# Epoch 14/500
# 43/43 - 0s - loss: 1.1348 - 69ms/epoch - 2ms/step
# Epoch 15/500
# 43/43 - 0s - loss: 1.1342 - 68ms/epoch - 2ms/step
# Epoch 16/500
# 43/43 - 0s - loss: 1.1338 - 60ms/epoch - 1ms/step
# Epoch 17/500
# 43/43 - 0s - loss: 1.1333 - 68ms/epoch - 2ms/step
# Epoch 18/500
# 43/43 - 0s - loss: 1.1329 - 61ms/epoch - 1ms/step
# Epoch 19/500
# 43/43 - 0s - loss: 1.1325 - 56ms/epoch - 1ms/step
# Epoch 20/500
# 43/43 - 0s - loss: 1.1320 - 60ms/epoch - 1ms/step
# Epoch 21/500
# 43/43 - 0s - loss: 1.1316 - 66ms/epoch - 2ms/step
# Epoch 22/500
# 43/43 - 0s - loss: 1.1312 - 60ms/epoch - 1ms/step
# Epoch 23/500
# 43/43 - 0s - loss: 1.1308 - 74ms/epoch - 2ms/step
# Epoch 24/500
# 43/43 - 0s - loss: 1.1304 - 61ms/epoch - 1ms/step
# Epoch 25/500
# 43/43 - 0s - loss: 1.1300 - 71ms/epoch - 2ms/step
# Epoch 26/500
# 43/43 - 0s - loss: 1.1297 - 69ms/epoch - 2ms/step
# Epoch 27/500
# 43/43 - 0s - loss: 1.1293 - 72ms/epoch - 2ms/step
# Epoch 28/500
# 43/43 - 0s - loss: 1.1290 - 71ms/epoch - 2ms/step
# Epoch 29/500
# 43/43 - 0s - loss: 1.1287 - 69ms/epoch - 2ms/step
# Epoch 30/500
# 43/43 - 0s - loss: 1.1284 - 64ms/epoch - 1ms/step
# Epoch 31/500
# 43/43 - 0s - loss: 1.1280 - 66ms/epoch - 2ms/step
# Epoch 32/500
# 43/43 - 0s - loss: 1.1277 - 72ms/epoch - 2ms/step
# Epoch 33/500
# 43/43 - 0s - loss: 1.1274 - 70ms/epoch - 2ms/step
# Epoch 34/500
# 43/43 - 0s - loss: 1.1271 - 74ms/epoch - 2ms/step
# Epoch 35/500
# 43/43 - 0s - loss: 1.1268 - 68ms/epoch - 2ms/step
# Epoch 36/500
# 43/43 - 0s - loss: 1.1266 - 69ms/epoch - 2ms/step
# Epoch 37/500
# 43/43 - 0s - loss: 1.1263 - 62ms/epoch - 1ms/step
# Epoch 38/500
# 43/43 - 0s - loss: 1.1260 - 90ms/epoch - 2ms/step
# Epoch 39/500
# 43/43 - 0s - loss: 1.1258 - 72ms/epoch - 2ms/step
# Epoch 40/500
# 43/43 - 0s - loss: 1.1255 - 73ms/epoch - 2ms/step
# Epoch 41/500
# 43/43 - 0s - loss: 1.1252 - 75ms/epoch - 2ms/step
# Epoch 42/500
# 43/43 - 0s - loss: 1.1249 - 92ms/epoch - 2ms/step
# Epoch 43/500
# 43/43 - 0s - loss: 1.1247 - 82ms/epoch - 2ms/step
# Epoch 44/500
# 43/43 - 0s - loss: 1.1244 - 82ms/epoch - 2ms/step
# Epoch 45/500
# 43/43 - 0s - loss: 1.1241 - 72ms/epoch - 2ms/step
# Epoch 46/500
# 43/43 - 0s - loss: 1.1239 - 65ms/epoch - 2ms/step
# Epoch 47/500
# 43/43 - 0s - loss: 1.1236 - 67ms/epoch - 2ms/step
# Epoch 48/500
# 43/43 - 0s - loss: 1.1234 - 60ms/epoch - 1ms/step
# Epoch 49/500
# 43/43 - 0s - loss: 1.1231 - 67ms/epoch - 2ms/step
# Epoch 50/500
# 43/43 - 0s - loss: 1.1229 - 58ms/epoch - 1ms/step
# Epoch 51/500
# 43/43 - 0s - loss: 1.1226 - 58ms/epoch - 1ms/step
# Epoch 52/500
# 43/43 - 0s - loss: 1.1224 - 67ms/epoch - 2ms/step
# Epoch 53/500
# 43/43 - 0s - loss: 1.1222 - 69ms/epoch - 2ms/step
# Epoch 54/500
# 43/43 - 0s - loss: 1.1219 - 61ms/epoch - 1ms/step
# Epoch 55/500
# 43/43 - 0s - loss: 1.1217 - 57ms/epoch - 1ms/step
# Epoch 56/500
# 43/43 - 0s - loss: 1.1215 - 58ms/epoch - 1ms/step
# Epoch 57/500
# 43/43 - 0s - loss: 1.1213 - 65ms/epoch - 2ms/step
# Epoch 58/500
# 43/43 - 0s - loss: 1.1211 - 57ms/epoch - 1ms/step
# Epoch 59/500
# 43/43 - 0s - loss: 1.1209 - 60ms/epoch - 1ms/step
# Epoch 60/500
# 43/43 - 0s - loss: 1.1207 - 67ms/epoch - 2ms/step
# Epoch 61/500
# 43/43 - 0s - loss: 1.1205 - 68ms/epoch - 2ms/step
# Epoch 62/500
# 43/43 - 0s - loss: 1.1203 - 72ms/epoch - 2ms/step
# Epoch 63/500
# 43/43 - 0s - loss: 1.1201 - 67ms/epoch - 2ms/step
# Epoch 64/500
# 43/43 - 0s - loss: 1.1199 - 73ms/epoch - 2ms/step
# Epoch 65/500
# 43/43 - 0s - loss: 1.1196 - 74ms/epoch - 2ms/step
# Epoch 66/500
# 43/43 - 0s - loss: 1.1195 - 69ms/epoch - 2ms/step
# Epoch 67/500
# 43/43 - 0s - loss: 1.1193 - 65ms/epoch - 2ms/step
# Epoch 68/500
# 43/43 - 0s - loss: 1.1191 - 71ms/epoch - 2ms/step
# Epoch 69/500
# 43/43 - 0s - loss: 1.1189 - 76ms/epoch - 2ms/step
# Epoch 70/500
# 43/43 - 0s - loss: 1.1187 - 73ms/epoch - 2ms/step
# Epoch 71/500
# 43/43 - 0s - loss: 1.1185 - 78ms/epoch - 2ms/step
# Epoch 72/500
# 43/43 - 0s - loss: 1.1183 - 67ms/epoch - 2ms/step
# Epoch 73/500
# 43/43 - 0s - loss: 1.1180 - 70ms/epoch - 2ms/step
# Epoch 74/500
# 43/43 - 0s - loss: 1.1179 - 69ms/epoch - 2ms/step
# Epoch 75/500
# 43/43 - 0s - loss: 1.1177 - 74ms/epoch - 2ms/step
# Epoch 76/500
# 43/43 - 0s - loss: 1.1174 - 66ms/epoch - 2ms/step
# Epoch 77/500
# 43/43 - 0s - loss: 1.1173 - 68ms/epoch - 2ms/step
# Epoch 78/500
# 43/43 - 0s - loss: 1.1171 - 62ms/epoch - 1ms/step
# Epoch 79/500
# 43/43 - 0s - loss: 1.1169 - 67ms/epoch - 2ms/step
# Epoch 80/500
# 43/43 - 0s - loss: 1.1167 - 60ms/epoch - 1ms/step
# Epoch 81/500
# 43/43 - 0s - loss: 1.1165 - 60ms/epoch - 1ms/step
# Epoch 82/500
# 43/43 - 0s - loss: 1.1163 - 64ms/epoch - 1ms/step
# Epoch 83/500
# 43/43 - 0s - loss: 1.1161 - 62ms/epoch - 1ms/step
# Epoch 84/500
# 43/43 - 0s - loss: 1.1160 - 72ms/epoch - 2ms/step
# Epoch 85/500
# 43/43 - 0s - loss: 1.1158 - 62ms/epoch - 1ms/step
# Epoch 86/500
# 43/43 - 0s - loss: 1.1156 - 62ms/epoch - 1ms/step
# Epoch 87/500
# 43/43 - 0s - loss: 1.1154 - 60ms/epoch - 1ms/step
# Epoch 88/500
# 43/43 - 0s - loss: 1.1153 - 61ms/epoch - 1ms/step
# Epoch 89/500
# 43/43 - 0s - loss: 1.1151 - 57ms/epoch - 1ms/step
# Epoch 90/500
# 43/43 - 0s - loss: 1.1149 - 66ms/epoch - 2ms/step
# Epoch 91/500
# 43/43 - 0s - loss: 1.1147 - 73ms/epoch - 2ms/step
# Epoch 92/500
# 43/43 - 0s - loss: 1.1147 - 72ms/epoch - 2ms/step
# Epoch 93/500
# 43/43 - 0s - loss: 1.1145 - 62ms/epoch - 1ms/step
# Epoch 94/500
# 43/43 - 0s - loss: 1.1143 - 63ms/epoch - 1ms/step
# Epoch 95/500
# 43/43 - 0s - loss: 1.1142 - 70ms/epoch - 2ms/step
# Epoch 96/500
# 43/43 - 0s - loss: 1.1140 - 59ms/epoch - 1ms/step
# Epoch 97/500
# 43/43 - 0s - loss: 1.1138 - 70ms/epoch - 2ms/step
# Epoch 98/500
# 43/43 - 0s - loss: 1.1137 - 66ms/epoch - 2ms/step
# Epoch 99/500
# 43/43 - 0s - loss: 1.1136 - 61ms/epoch - 1ms/step
# Epoch 100/500
# 43/43 - 0s - loss: 1.1134 - 74ms/epoch - 2ms/step
# Epoch 101/500
# 43/43 - 0s - loss: 1.1132 - 66ms/epoch - 2ms/step
# Epoch 102/500
# 43/43 - 0s - loss: 1.1130 - 70ms/epoch - 2ms/step
# Epoch 103/500
# 43/43 - 0s - loss: 1.1129 - 68ms/epoch - 2ms/step
# Epoch 104/500
# 43/43 - 0s - loss: 1.1127 - 66ms/epoch - 2ms/step
# Epoch 105/500
# 43/43 - 0s - loss: 1.1126 - 68ms/epoch - 2ms/step
# Epoch 106/500
# 43/43 - 0s - loss: 1.1124 - 69ms/epoch - 2ms/step
# Epoch 107/500
# 43/43 - 0s - loss: 1.1123 - 68ms/epoch - 2ms/step
# Epoch 108/500
# 43/43 - 0s - loss: 1.1121 - 66ms/epoch - 2ms/step
# Epoch 109/500
# 43/43 - 0s - loss: 1.1119 - 75ms/epoch - 2ms/step
# Epoch 110/500
# 43/43 - 0s - loss: 1.1117 - 78ms/epoch - 2ms/step
# Epoch 111/500
# 43/43 - 0s - loss: 1.1115 - 62ms/epoch - 1ms/step
# Epoch 112/500
# 43/43 - 0s - loss: 1.1114 - 71ms/epoch - 2ms/step
# Epoch 113/500
# 43/43 - 0s - loss: 1.1112 - 62ms/epoch - 1ms/step
# Epoch 114/500
# 43/43 - 0s - loss: 1.1110 - 64ms/epoch - 1ms/step
# Epoch 115/500
# 43/43 - 0s - loss: 1.1108 - 82ms/epoch - 2ms/step
# Epoch 116/500
# 43/43 - 0s - loss: 1.1107 - 68ms/epoch - 2ms/step
# Epoch 117/500
# 43/43 - 0s - loss: 1.1105 - 67ms/epoch - 2ms/step
# Epoch 118/500
# 43/43 - 0s - loss: 1.1104 - 63ms/epoch - 1ms/step
# Epoch 119/500
# 43/43 - 0s - loss: 1.1102 - 61ms/epoch - 1ms/step
# Epoch 120/500
# 43/43 - 0s - loss: 1.1101 - 65ms/epoch - 2ms/step
# Epoch 121/500
# 43/43 - 0s - loss: 1.1099 - 77ms/epoch - 2ms/step
# Epoch 122/500
# 43/43 - 0s - loss: 1.1098 - 68ms/epoch - 2ms/step
# Epoch 123/500
# 43/43 - 0s - loss: 1.1097 - 79ms/epoch - 2ms/step
# Epoch 124/500
# 43/43 - 0s - loss: 1.1095 - 70ms/epoch - 2ms/step
# Epoch 125/500
# 43/43 - 0s - loss: 1.1094 - 71ms/epoch - 2ms/step
# Epoch 126/500
# 43/43 - 0s - loss: 1.1092 - 69ms/epoch - 2ms/step
# Epoch 127/500
# 43/43 - 0s - loss: 1.1091 - 68ms/epoch - 2ms/step
# Epoch 128/500
# 43/43 - 0s - loss: 1.1090 - 71ms/epoch - 2ms/step
# Epoch 129/500
# 43/43 - 0s - loss: 1.1088 - 69ms/epoch - 2ms/step
# Epoch 130/500
# 43/43 - 0s - loss: 1.1087 - 82ms/epoch - 2ms/step
# Epoch 131/500
# 43/43 - 0s - loss: 1.1085 - 71ms/epoch - 2ms/step
# Epoch 132/500
# 43/43 - 0s - loss: 1.1084 - 65ms/epoch - 2ms/step
# Epoch 133/500
# 43/43 - 0s - loss: 1.1082 - 67ms/epoch - 2ms/step
# Epoch 134/500
# 43/43 - 0s - loss: 1.1081 - 68ms/epoch - 2ms/step
# Epoch 135/500
# 43/43 - 0s - loss: 1.1080 - 70ms/epoch - 2ms/step
# Epoch 136/500
# 43/43 - 0s - loss: 1.1078 - 73ms/epoch - 2ms/step
# Epoch 137/500
# 43/43 - 0s - loss: 1.1077 - 73ms/epoch - 2ms/step
# Epoch 138/500
# 43/43 - 0s - loss: 1.1075 - 78ms/epoch - 2ms/step
# Epoch 139/500
# 43/43 - 0s - loss: 1.1074 - 76ms/epoch - 2ms/step
# Epoch 140/500
# 43/43 - 0s - loss: 1.1072 - 72ms/epoch - 2ms/step
# Epoch 141/500
# 43/43 - 0s - loss: 1.1071 - 69ms/epoch - 2ms/step
# Epoch 142/500
# 43/43 - 0s - loss: 1.1070 - 66ms/epoch - 2ms/step
# Epoch 143/500
# 43/43 - 0s - loss: 1.1069 - 74ms/epoch - 2ms/step
# Epoch 144/500
# 43/43 - 0s - loss: 1.1067 - 61ms/epoch - 1ms/step
# Epoch 145/500
# 43/43 - 0s - loss: 1.1066 - 77ms/epoch - 2ms/step
# Epoch 146/500
# 43/43 - 0s - loss: 1.1065 - 58ms/epoch - 1ms/step
# Epoch 147/500
# 43/43 - 0s - loss: 1.1063 - 59ms/epoch - 1ms/step
# Epoch 148/500
# 43/43 - 0s - loss: 1.1062 - 59ms/epoch - 1ms/step
# Epoch 149/500
# 43/43 - 0s - loss: 1.1060 - 69ms/epoch - 2ms/step
# Epoch 150/500
# 43/43 - 0s - loss: 1.1059 - 58ms/epoch - 1ms/step
# Epoch 151/500
# 43/43 - 0s - loss: 1.1058 - 58ms/epoch - 1ms/step
# Epoch 152/500
# 43/43 - 0s - loss: 1.1056 - 58ms/epoch - 1ms/step
# Epoch 153/500
# 43/43 - 0s - loss: 1.1055 - 64ms/epoch - 1ms/step
# Epoch 154/500
# 43/43 - 0s - loss: 1.1054 - 59ms/epoch - 1ms/step
# Epoch 155/500
# 43/43 - 0s - loss: 1.1053 - 58ms/epoch - 1ms/step
# Epoch 156/500
# 43/43 - 0s - loss: 1.1052 - 59ms/epoch - 1ms/step
# Epoch 157/500
# 43/43 - 0s - loss: 1.1051 - 60ms/epoch - 1ms/step
# Epoch 158/500
# 43/43 - 0s - loss: 1.1049 - 61ms/epoch - 1ms/step
# Epoch 159/500
# 43/43 - 0s - loss: 1.1048 - 75ms/epoch - 2ms/step
# Epoch 160/500
# 43/43 - 0s - loss: 1.1047 - 73ms/epoch - 2ms/step
# Epoch 161/500
# 43/43 - 0s - loss: 1.1045 - 87ms/epoch - 2ms/step
# Epoch 162/500
# 43/43 - 0s - loss: 1.1044 - 87ms/epoch - 2ms/step
# Epoch 163/500
# 43/43 - 0s - loss: 1.1043 - 77ms/epoch - 2ms/step
# Epoch 164/500
# 43/43 - 0s - loss: 1.1042 - 74ms/epoch - 2ms/step
# Epoch 165/500
# 43/43 - 0s - loss: 1.1041 - 64ms/epoch - 1ms/step
# Epoch 166/500
# 43/43 - 0s - loss: 1.1039 - 58ms/epoch - 1ms/step
# Epoch 167/500
# 43/43 - 0s - loss: 1.1038 - 65ms/epoch - 2ms/step
# Epoch 168/500
# 43/43 - 0s - loss: 1.1037 - 62ms/epoch - 1ms/step
# Epoch 169/500
# 43/43 - 0s - loss: 1.1036 - 58ms/epoch - 1ms/step
# Epoch 170/500
# 43/43 - 0s - loss: 1.1034 - 63ms/epoch - 1ms/step
# Epoch 171/500
# 43/43 - 0s - loss: 1.1033 - 87ms/epoch - 2ms/step
# Epoch 172/500
# 43/43 - 0s - loss: 1.1032 - 62ms/epoch - 1ms/step
# Epoch 173/500
# 43/43 - 0s - loss: 1.1030 - 57ms/epoch - 1ms/step
# Epoch 174/500
# 43/43 - 0s - loss: 1.1029 - 62ms/epoch - 1ms/step
# Epoch 175/500
# 43/43 - 0s - loss: 1.1028 - 64ms/epoch - 1ms/step
# Epoch 176/500
# 43/43 - 0s - loss: 1.1027 - 59ms/epoch - 1ms/step
# Epoch 177/500
# 43/43 - 0s - loss: 1.1025 - 74ms/epoch - 2ms/step
# Epoch 178/500
# 43/43 - 0s - loss: 1.1024 - 58ms/epoch - 1ms/step
# Epoch 179/500
# 43/43 - 0s - loss: 1.1023 - 82ms/epoch - 2ms/step
# Epoch 180/500
# 43/43 - 0s - loss: 1.1022 - 74ms/epoch - 2ms/step
# Epoch 181/500
# 43/43 - 0s - loss: 1.1021 - 82ms/epoch - 2ms/step
# Epoch 182/500
# 43/43 - 0s - loss: 1.1020 - 64ms/epoch - 1ms/step
# Epoch 183/500
# 43/43 - 0s - loss: 1.1019 - 62ms/epoch - 1ms/step
# Epoch 184/500
# 43/43 - 0s - loss: 1.1018 - 60ms/epoch - 1ms/step
# Epoch 185/500
# 43/43 - 0s - loss: 1.1016 - 68ms/epoch - 2ms/step
# Epoch 186/500
# 43/43 - 0s - loss: 1.1015 - 84ms/epoch - 2ms/step
# Epoch 187/500
# 43/43 - 0s - loss: 1.1014 - 73ms/epoch - 2ms/step
# Epoch 188/500
# 43/43 - 0s - loss: 1.1013 - 60ms/epoch - 1ms/step
# Epoch 189/500
# 43/43 - 0s - loss: 1.1012 - 59ms/epoch - 1ms/step
# Epoch 190/500
# 43/43 - 0s - loss: 1.1011 - 59ms/epoch - 1ms/step
# Epoch 191/500
# 43/43 - 0s - loss: 1.1009 - 62ms/epoch - 1ms/step
# Epoch 192/500
# 43/43 - 0s - loss: 1.1009 - 72ms/epoch - 2ms/step
# Epoch 193/500
# 43/43 - 0s - loss: 1.1008 - 66ms/epoch - 2ms/step
# Epoch 194/500
# 43/43 - 0s - loss: 1.1007 - 64ms/epoch - 1ms/step
# Epoch 195/500
# 43/43 - 0s - loss: 1.1005 - 62ms/epoch - 1ms/step
# Epoch 196/500
# 43/43 - 0s - loss: 1.1004 - 58ms/epoch - 1ms/step
# Epoch 197/500
# 43/43 - 0s - loss: 1.1004 - 62ms/epoch - 1ms/step
# Epoch 198/500
# 43/43 - 0s - loss: 1.1003 - 63ms/epoch - 1ms/step
# Epoch 199/500
# 43/43 - 0s - loss: 1.1001 - 61ms/epoch - 1ms/step
# Epoch 200/500
# 43/43 - 0s - loss: 1.1001 - 64ms/epoch - 1ms/step
# Epoch 201/500
# 43/43 - 0s - loss: 1.0999 - 67ms/epoch - 2ms/step
# Epoch 202/500
# 43/43 - 0s - loss: 1.0998 - 67ms/epoch - 2ms/step
# Epoch 203/500
# 43/43 - 0s - loss: 1.0997 - 85ms/epoch - 2ms/step
# Epoch 204/500
# 43/43 - 0s - loss: 1.0996 - 65ms/epoch - 2ms/step
# Epoch 205/500
# 43/43 - 0s - loss: 1.0996 - 64ms/epoch - 1ms/step
# Epoch 206/500
# 43/43 - 0s - loss: 1.0994 - 67ms/epoch - 2ms/step
# Epoch 207/500
# 43/43 - 0s - loss: 1.0993 - 72ms/epoch - 2ms/step
# Epoch 208/500
# 43/43 - 0s - loss: 1.0993 - 89ms/epoch - 2ms/step
# Epoch 209/500
# 43/43 - 0s - loss: 1.0991 - 67ms/epoch - 2ms/step
# Epoch 210/500
# 43/43 - 0s - loss: 1.0991 - 65ms/epoch - 2ms/step
# Epoch 211/500
# 43/43 - 0s - loss: 1.0989 - 61ms/epoch - 1ms/step
# Epoch 212/500
# 43/43 - 0s - loss: 1.0988 - 69ms/epoch - 2ms/step
# Epoch 213/500
# 43/43 - 0s - loss: 1.0988 - 68ms/epoch - 2ms/step
# Epoch 214/500
# 43/43 - 0s - loss: 1.0986 - 67ms/epoch - 2ms/step
# Epoch 215/500
# 43/43 - 0s - loss: 1.0985 - 67ms/epoch - 2ms/step
# Epoch 216/500
# 43/43 - 0s - loss: 1.0984 - 69ms/epoch - 2ms/step
# Epoch 217/500
# 43/43 - 0s - loss: 1.0983 - 62ms/epoch - 1ms/step
# Epoch 218/500
# 43/43 - 0s - loss: 1.0982 - 65ms/epoch - 2ms/step
# Epoch 219/500
# 43/43 - 0s - loss: 1.0981 - 66ms/epoch - 2ms/step
# Epoch 220/500
# 43/43 - 0s - loss: 1.0980 - 71ms/epoch - 2ms/step
# Epoch 221/500
# 43/43 - 0s - loss: 1.0979 - 71ms/epoch - 2ms/step
# Epoch 222/500
# 43/43 - 0s - loss: 1.0978 - 63ms/epoch - 1ms/step
# Epoch 223/500
# 43/43 - 0s - loss: 1.0977 - 80ms/epoch - 2ms/step
# Epoch 224/500
# 43/43 - 0s - loss: 1.0976 - 73ms/epoch - 2ms/step
# Epoch 225/500
# 43/43 - 0s - loss: 1.0975 - 68ms/epoch - 2ms/step
# Epoch 226/500
# 43/43 - 0s - loss: 1.0974 - 71ms/epoch - 2ms/step
# Epoch 227/500
# 43/43 - 0s - loss: 1.0973 - 67ms/epoch - 2ms/step
# Epoch 228/500
# 43/43 - 0s - loss: 1.0971 - 61ms/epoch - 1ms/step
# Epoch 229/500
# 43/43 - 0s - loss: 1.0971 - 61ms/epoch - 1ms/step
# Epoch 230/500
# 43/43 - 0s - loss: 1.0970 - 71ms/epoch - 2ms/step
# Epoch 231/500
# 43/43 - 0s - loss: 1.0970 - 67ms/epoch - 2ms/step
# Epoch 232/500
# 43/43 - 0s - loss: 1.0968 - 64ms/epoch - 1ms/step
# Epoch 233/500
# 43/43 - 0s - loss: 1.0967 - 63ms/epoch - 1ms/step
# Epoch 234/500
# 43/43 - 0s - loss: 1.0966 - 60ms/epoch - 1ms/step
# Epoch 235/500
# 43/43 - 0s - loss: 1.0965 - 63ms/epoch - 1ms/step
# Epoch 236/500
# 43/43 - 0s - loss: 1.0964 - 68ms/epoch - 2ms/step
# Epoch 237/500
# 43/43 - 0s - loss: 1.0963 - 70ms/epoch - 2ms/step
# Epoch 238/500
# 43/43 - 0s - loss: 1.0962 - 66ms/epoch - 2ms/step
# Epoch 239/500
# 43/43 - 0s - loss: 1.0961 - 80ms/epoch - 2ms/step
# Epoch 240/500
# 43/43 - 0s - loss: 1.0960 - 63ms/epoch - 1ms/step
# Epoch 241/500
# 43/43 - 0s - loss: 1.0959 - 69ms/epoch - 2ms/step
# Epoch 242/500
# 43/43 - 0s - loss: 1.0959 - 66ms/epoch - 2ms/step
# Epoch 243/500
# 43/43 - 0s - loss: 1.0958 - 65ms/epoch - 2ms/step
# Epoch 244/500
# 43/43 - 0s - loss: 1.0956 - 69ms/epoch - 2ms/step
# Epoch 245/500
# 43/43 - 0s - loss: 1.0956 - 61ms/epoch - 1ms/step
# Epoch 246/500
# 43/43 - 0s - loss: 1.0955 - 68ms/epoch - 2ms/step
# Epoch 247/500
# 43/43 - 0s - loss: 1.0954 - 75ms/epoch - 2ms/step
# Epoch 248/500
# 43/43 - 0s - loss: 1.0953 - 71ms/epoch - 2ms/step
# Epoch 249/500
# 43/43 - 0s - loss: 1.0952 - 64ms/epoch - 1ms/step
# Epoch 250/500
# 43/43 - 0s - loss: 1.0951 - 71ms/epoch - 2ms/step
# Epoch 251/500
# 43/43 - 0s - loss: 1.0950 - 71ms/epoch - 2ms/step
# Epoch 252/500
# 43/43 - 0s - loss: 1.0950 - 67ms/epoch - 2ms/step
# Epoch 253/500
# 43/43 - 0s - loss: 1.0949 - 70ms/epoch - 2ms/step
# Epoch 254/500
# 43/43 - 0s - loss: 1.0948 - 82ms/epoch - 2ms/step
# Epoch 255/500
# 43/43 - 0s - loss: 1.0947 - 72ms/epoch - 2ms/step
# Epoch 256/500
# 43/43 - 0s - loss: 1.0946 - 67ms/epoch - 2ms/step
# Epoch 257/500
# 43/43 - 0s - loss: 1.0946 - 67ms/epoch - 2ms/step
# Epoch 258/500
# 43/43 - 0s - loss: 1.0944 - 65ms/epoch - 2ms/step
# Epoch 259/500
# 43/43 - 0s - loss: 1.0944 - 66ms/epoch - 2ms/step
# Epoch 260/500
# 43/43 - 0s - loss: 1.0943 - 60ms/epoch - 1ms/step
# Epoch 261/500
# 43/43 - 0s - loss: 1.0941 - 58ms/epoch - 1ms/step
# Epoch 262/500
# 43/43 - 0s - loss: 1.0941 - 58ms/epoch - 1ms/step
# Epoch 263/500
# 43/43 - 0s - loss: 1.0940 - 59ms/epoch - 1ms/step
# Epoch 264/500
# 43/43 - 0s - loss: 1.0939 - 69ms/epoch - 2ms/step
# Epoch 265/500
# 43/43 - 0s - loss: 1.0938 - 59ms/epoch - 1ms/step
# Epoch 266/500
# 43/43 - 0s - loss: 1.0937 - 69ms/epoch - 2ms/step
# Epoch 267/500
# 43/43 - 0s - loss: 1.0936 - 72ms/epoch - 2ms/step
# Epoch 268/500
# 43/43 - 0s - loss: 1.0935 - 59ms/epoch - 1ms/step
# Epoch 269/500
# 43/43 - 0s - loss: 1.0935 - 57ms/epoch - 1ms/step
# Epoch 270/500
# 43/43 - 0s - loss: 1.0933 - 59ms/epoch - 1ms/step
# Epoch 271/500
# 43/43 - 0s - loss: 1.0934 - 84ms/epoch - 2ms/step
# Epoch 272/500
# 43/43 - 0s - loss: 1.0932 - 63ms/epoch - 1ms/step
# Epoch 273/500
# 43/43 - 0s - loss: 1.0931 - 62ms/epoch - 1ms/step
# Epoch 274/500
# 43/43 - 0s - loss: 1.0931 - 62ms/epoch - 1ms/step
# Epoch 275/500
# 43/43 - 0s - loss: 1.0929 - 62ms/epoch - 1ms/step
# Epoch 276/500
# 43/43 - 0s - loss: 1.0929 - 68ms/epoch - 2ms/step
# Epoch 277/500
# 43/43 - 0s - loss: 1.0928 - 64ms/epoch - 1ms/step
# Epoch 278/500
# 43/43 - 0s - loss: 1.0928 - 64ms/epoch - 1ms/step
# Epoch 279/500
# 43/43 - 0s - loss: 1.0927 - 62ms/epoch - 1ms/step
# Epoch 280/500
# 43/43 - 0s - loss: 1.0925 - 65ms/epoch - 2ms/step
# Epoch 281/500
# 43/43 - 0s - loss: 1.0926 - 59ms/epoch - 1ms/step
# Epoch 282/500
# 43/43 - 0s - loss: 1.0924 - 58ms/epoch - 1ms/step
# Epoch 283/500
# 43/43 - 0s - loss: 1.0923 - 60ms/epoch - 1ms/step
# Epoch 284/500
# 43/43 - 0s - loss: 1.0923 - 59ms/epoch - 1ms/step
# Epoch 285/500
# 43/43 - 0s - loss: 1.0922 - 72ms/epoch - 2ms/step
# Epoch 286/500
# 43/43 - 0s - loss: 1.0921 - 65ms/epoch - 2ms/step
# Epoch 287/500
# 43/43 - 0s - loss: 1.0920 - 81ms/epoch - 2ms/step
# Epoch 288/500
# 43/43 - 0s - loss: 1.0919 - 64ms/epoch - 1ms/step
# Epoch 289/500
# 43/43 - 0s - loss: 1.0918 - 60ms/epoch - 1ms/step
# Epoch 290/500
# 43/43 - 0s - loss: 1.0917 - 63ms/epoch - 1ms/step
# Epoch 291/500
# 43/43 - 0s - loss: 1.0917 - 60ms/epoch - 1ms/step
# Epoch 292/500
# 43/43 - 0s - loss: 1.0916 - 65ms/epoch - 2ms/step
# Epoch 293/500
# 43/43 - 0s - loss: 1.0915 - 67ms/epoch - 2ms/step
# Epoch 294/500
# 43/43 - 0s - loss: 1.0915 - 62ms/epoch - 1ms/step
# Epoch 295/500
# 43/43 - 0s - loss: 1.0914 - 60ms/epoch - 1ms/step
# Epoch 296/500
# 43/43 - 0s - loss: 1.0913 - 70ms/epoch - 2ms/step
# Epoch 297/500
# 43/43 - 0s - loss: 1.0913 - 61ms/epoch - 1ms/step
# Epoch 298/500
# 43/43 - 0s - loss: 1.0912 - 61ms/epoch - 1ms/step
# Epoch 299/500
# 43/43 - 0s - loss: 1.0912 - 58ms/epoch - 1ms/step
# Epoch 300/500
# 43/43 - 0s - loss: 1.0911 - 58ms/epoch - 1ms/step
# Epoch 301/500
# 43/43 - 0s - loss: 1.0911 - 80ms/epoch - 2ms/step
# Epoch 302/500
# 43/43 - 0s - loss: 1.0909 - 76ms/epoch - 2ms/step
# Epoch 303/500
# 43/43 - 0s - loss: 1.0909 - 78ms/epoch - 2ms/step
# Epoch 304/500
# 43/43 - 0s - loss: 1.0908 - 63ms/epoch - 1ms/step
# Epoch 305/500
# 43/43 - 0s - loss: 1.0907 - 57ms/epoch - 1ms/step
# Epoch 306/500
# 43/43 - 0s - loss: 1.0907 - 67ms/epoch - 2ms/step
# Epoch 307/500
# 43/43 - 0s - loss: 1.0906 - 79ms/epoch - 2ms/step
# Epoch 308/500
# 43/43 - 0s - loss: 1.0905 - 66ms/epoch - 2ms/step
# Epoch 309/500
# 43/43 - 0s - loss: 1.0904 - 59ms/epoch - 1ms/step
# Epoch 310/500
# 43/43 - 0s - loss: 1.0903 - 61ms/epoch - 1ms/step
# Epoch 311/500
# 43/43 - 0s - loss: 1.0903 - 67ms/epoch - 2ms/step
# Epoch 312/500
# 43/43 - 0s - loss: 1.0902 - 64ms/epoch - 1ms/step
# Epoch 313/500
# 43/43 - 0s - loss: 1.0902 - 63ms/epoch - 1ms/step
# Epoch 314/500
# 43/43 - 0s - loss: 1.0901 - 62ms/epoch - 1ms/step
# Epoch 315/500
# 43/43 - 0s - loss: 1.0900 - 61ms/epoch - 1ms/step
# Epoch 316/500
# 43/43 - 0s - loss: 1.0899 - 59ms/epoch - 1ms/step
# Epoch 317/500
# 43/43 - 0s - loss: 1.0899 - 71ms/epoch - 2ms/step
# Epoch 318/500
# 43/43 - 0s - loss: 1.0898 - 65ms/epoch - 2ms/step
# Epoch 319/500
# 43/43 - 0s - loss: 1.0897 - 75ms/epoch - 2ms/step
# Epoch 320/500
# 43/43 - 0s - loss: 1.0897 - 63ms/epoch - 1ms/step
# Epoch 321/500
# 43/43 - 0s - loss: 1.0896 - 61ms/epoch - 1ms/step
# Epoch 322/500
# 43/43 - 0s - loss: 1.0895 - 60ms/epoch - 1ms/step
# Epoch 323/500
# 43/43 - 0s - loss: 1.0894 - 61ms/epoch - 1ms/step
# Epoch 324/500
# 43/43 - 0s - loss: 1.0893 - 66ms/epoch - 2ms/step
# Epoch 325/500
# 43/43 - 0s - loss: 1.0893 - 65ms/epoch - 2ms/step
# Epoch 326/500
# 43/43 - 0s - loss: 1.0892 - 72ms/epoch - 2ms/step
# Epoch 327/500
# 43/43 - 0s - loss: 1.0892 - 64ms/epoch - 1ms/step
# Epoch 328/500
# 43/43 - 0s - loss: 1.0891 - 79ms/epoch - 2ms/step
# Epoch 329/500
# 43/43 - 0s - loss: 1.0890 - 64ms/epoch - 1ms/step
# Epoch 330/500
# 43/43 - 0s - loss: 1.0890 - 66ms/epoch - 2ms/step
# Epoch 331/500
# 43/43 - 0s - loss: 1.0889 - 69ms/epoch - 2ms/step
# Epoch 332/500
# 43/43 - 0s - loss: 1.0888 - 75ms/epoch - 2ms/step
# Epoch 333/500
# 43/43 - 0s - loss: 1.0888 - 65ms/epoch - 2ms/step
# Epoch 334/500
# 43/43 - 0s - loss: 1.0887 - 67ms/epoch - 2ms/step
# Epoch 335/500
# 43/43 - 0s - loss: 1.0886 - 72ms/epoch - 2ms/step
# Epoch 336/500
# 43/43 - 0s - loss: 1.0885 - 73ms/epoch - 2ms/step
# Epoch 337/500
# 43/43 - 0s - loss: 1.0885 - 62ms/epoch - 1ms/step
# Epoch 338/500
# 43/43 - 0s - loss: 1.0884 - 77ms/epoch - 2ms/step
# Epoch 339/500
# 43/43 - 0s - loss: 1.0883 - 69ms/epoch - 2ms/step
# Epoch 340/500
# 43/43 - 0s - loss: 1.0882 - 64ms/epoch - 1ms/step
# Epoch 341/500
# 43/43 - 0s - loss: 1.0881 - 66ms/epoch - 2ms/step
# Epoch 342/500
# 43/43 - 0s - loss: 1.0881 - 65ms/epoch - 2ms/step
# Epoch 343/500
# 43/43 - 0s - loss: 1.0881 - 60ms/epoch - 1ms/step
# Epoch 344/500
# 43/43 - 0s - loss: 1.0880 - 62ms/epoch - 1ms/step
# Epoch 345/500
# 43/43 - 0s - loss: 1.0879 - 66ms/epoch - 2ms/step
# Epoch 346/500
# 43/43 - 0s - loss: 1.0879 - 63ms/epoch - 1ms/step
# Epoch 347/500
# 43/43 - 0s - loss: 1.0878 - 71ms/epoch - 2ms/step
# Epoch 348/500
# 43/43 - 0s - loss: 1.0877 - 63ms/epoch - 1ms/step
# Epoch 349/500
# 43/43 - 0s - loss: 1.0876 - 68ms/epoch - 2ms/step
# Epoch 350/500
# 43/43 - 0s - loss: 1.0876 - 79ms/epoch - 2ms/step
# Epoch 351/500
# 43/43 - 0s - loss: 1.0875 - 69ms/epoch - 2ms/step
# Epoch 352/500
# 43/43 - 0s - loss: 1.0874 - 62ms/epoch - 1ms/step
# Epoch 353/500
# 43/43 - 0s - loss: 1.0873 - 69ms/epoch - 2ms/step
# Epoch 354/500
# 43/43 - 0s - loss: 1.0873 - 63ms/epoch - 1ms/step
# Epoch 355/500
# 43/43 - 0s - loss: 1.0873 - 70ms/epoch - 2ms/step
# Epoch 356/500
# 43/43 - 0s - loss: 1.0872 - 67ms/epoch - 2ms/step
# Epoch 357/500
# 43/43 - 0s - loss: 1.0871 - 66ms/epoch - 2ms/step
# Epoch 358/500
# 43/43 - 0s - loss: 1.0871 - 61ms/epoch - 1ms/step
# Epoch 359/500
# 43/43 - 0s - loss: 1.0870 - 64ms/epoch - 1ms/step
# Epoch 360/500
# 43/43 - 0s - loss: 1.0869 - 74ms/epoch - 2ms/step
# Epoch 361/500
# 43/43 - 0s - loss: 1.0869 - 61ms/epoch - 1ms/step
# Epoch 362/500
# 43/43 - 0s - loss: 1.0868 - 68ms/epoch - 2ms/step
# Epoch 363/500
# 43/43 - 0s - loss: 1.0867 - 61ms/epoch - 1ms/step
# Epoch 364/500
# 43/43 - 0s - loss: 1.0867 - 62ms/epoch - 1ms/step
# Epoch 365/500
# 43/43 - 0s - loss: 1.0867 - 66ms/epoch - 2ms/step
# Epoch 366/500
# 43/43 - 0s - loss: 1.0865 - 79ms/epoch - 2ms/step
# Epoch 367/500
# 43/43 - 0s - loss: 1.0865 - 65ms/epoch - 2ms/step
# Epoch 368/500
# 43/43 - 0s - loss: 1.0865 - 62ms/epoch - 1ms/step
# Epoch 369/500
# 43/43 - 0s - loss: 1.0864 - 67ms/epoch - 2ms/step
# Epoch 370/500
# 43/43 - 0s - loss: 1.0863 - 73ms/epoch - 2ms/step
# Epoch 371/500
# 43/43 - 0s - loss: 1.0864 - 63ms/epoch - 1ms/step
# Epoch 372/500
# 43/43 - 0s - loss: 1.0862 - 72ms/epoch - 2ms/step
# Epoch 373/500
# 43/43 - 0s - loss: 1.0861 - 66ms/epoch - 2ms/step
# Epoch 374/500
# 43/43 - 0s - loss: 1.0861 - 64ms/epoch - 1ms/step
# Epoch 375/500
# 43/43 - 0s - loss: 1.0860 - 63ms/epoch - 1ms/step
# Epoch 376/500
# 43/43 - 0s - loss: 1.0860 - 67ms/epoch - 2ms/step
# Epoch 377/500
# 43/43 - 0s - loss: 1.0860 - 67ms/epoch - 2ms/step
# Epoch 378/500
# 43/43 - 0s - loss: 1.0858 - 67ms/epoch - 2ms/step
# Epoch 379/500
# 43/43 - 0s - loss: 1.0857 - 68ms/epoch - 2ms/step
# Epoch 380/500
# 43/43 - 0s - loss: 1.0856 - 62ms/epoch - 1ms/step
# Epoch 381/500
# 43/43 - 0s - loss: 1.0856 - 65ms/epoch - 2ms/step
# Epoch 382/500
# 43/43 - 0s - loss: 1.0856 - 79ms/epoch - 2ms/step
# Epoch 383/500
# 43/43 - 0s - loss: 1.0855 - 64ms/epoch - 1ms/step
# Epoch 384/500
# 43/43 - 0s - loss: 1.0854 - 67ms/epoch - 2ms/step
# Epoch 385/500
# 43/43 - 0s - loss: 1.0853 - 68ms/epoch - 2ms/step
# Epoch 386/500
# 43/43 - 0s - loss: 1.0854 - 80ms/epoch - 2ms/step
# Epoch 387/500
# 43/43 - 0s - loss: 1.0853 - 68ms/epoch - 2ms/step
# Epoch 388/500
# 43/43 - 0s - loss: 1.0852 - 63ms/epoch - 1ms/step
# Epoch 389/500
# 43/43 - 0s - loss: 1.0851 - 61ms/epoch - 1ms/step
# Epoch 390/500
# 43/43 - 0s - loss: 1.0850 - 62ms/epoch - 1ms/step
# Epoch 391/500
# 43/43 - 0s - loss: 1.0849 - 59ms/epoch - 1ms/step
# Epoch 392/500
# 43/43 - 0s - loss: 1.0849 - 63ms/epoch - 1ms/step
# Epoch 393/500
# 43/43 - 0s - loss: 1.0849 - 61ms/epoch - 1ms/step
# Epoch 394/500
# 43/43 - 0s - loss: 1.0849 - 62ms/epoch - 1ms/step
# Epoch 395/500
# 43/43 - 0s - loss: 1.0847 - 59ms/epoch - 1ms/step
# Epoch 396/500
# 43/43 - 0s - loss: 1.0847 - 58ms/epoch - 1ms/step
# Epoch 397/500
# 43/43 - 0s - loss: 1.0847 - 61ms/epoch - 1ms/step
# Epoch 398/500
# 43/43 - 0s - loss: 1.0847 - 85ms/epoch - 2ms/step
# Epoch 399/500
# 43/43 - 0s - loss: 1.0846 - 59ms/epoch - 1ms/step
# Epoch 400/500
# 43/43 - 0s - loss: 1.0845 - 84ms/epoch - 2ms/step
# Epoch 401/500
# 43/43 - 0s - loss: 1.0846 - 61ms/epoch - 1ms/step
# Epoch 402/500
# 43/43 - 0s - loss: 1.0844 - 59ms/epoch - 1ms/step
# Epoch 403/500
# 43/43 - 0s - loss: 1.0843 - 59ms/epoch - 1ms/step
# Epoch 404/500
# 43/43 - 0s - loss: 1.0844 - 61ms/epoch - 1ms/step
# Epoch 405/500
# 43/43 - 0s - loss: 1.0843 - 60ms/epoch - 1ms/step
# Epoch 406/500
# 43/43 - 0s - loss: 1.0842 - 59ms/epoch - 1ms/step
# Epoch 407/500
# 43/43 - 0s - loss: 1.0841 - 64ms/epoch - 1ms/step
# Epoch 408/500
# 43/43 - 0s - loss: 1.0841 - 64ms/epoch - 1ms/step
# Epoch 409/500
# 43/43 - 0s - loss: 1.0840 - 62ms/epoch - 1ms/step
# Epoch 410/500
# 43/43 - 0s - loss: 1.0840 - 61ms/epoch - 1ms/step
# Epoch 411/500
# 43/43 - 0s - loss: 1.0839 - 62ms/epoch - 1ms/step
# Epoch 412/500
# 43/43 - 0s - loss: 1.0839 - 58ms/epoch - 1ms/step
# Epoch 413/500
# 43/43 - 0s - loss: 1.0838 - 66ms/epoch - 2ms/step
# Epoch 414/500
# 43/43 - 0s - loss: 1.0838 - 76ms/epoch - 2ms/step
# Epoch 415/500
# 43/43 - 0s - loss: 1.0837 - 84ms/epoch - 2ms/step
# Epoch 416/500
# 43/43 - 0s - loss: 1.0836 - 79ms/epoch - 2ms/step
# Epoch 417/500
# 43/43 - 0s - loss: 1.0836 - 62ms/epoch - 1ms/step
# Epoch 418/500
# 43/43 - 0s - loss: 1.0836 - 59ms/epoch - 1ms/step
# Epoch 419/500
# 43/43 - 0s - loss: 1.0836 - 60ms/epoch - 1ms/step
# Epoch 420/500
# 43/43 - 0s - loss: 1.0835 - 61ms/epoch - 1ms/step
# Epoch 421/500
# 43/43 - 0s - loss: 1.0834 - 62ms/epoch - 1ms/step
# Epoch 422/500
# 43/43 - 0s - loss: 1.0834 - 69ms/epoch - 2ms/step
# Epoch 423/500
# 43/43 - 0s - loss: 1.0833 - 64ms/epoch - 1ms/step
# Epoch 424/500
# 43/43 - 0s - loss: 1.0832 - 61ms/epoch - 1ms/step
# Epoch 425/500
# 43/43 - 0s - loss: 1.0832 - 66ms/epoch - 2ms/step
# Epoch 426/500
# 43/43 - 0s - loss: 1.0832 - 65ms/epoch - 2ms/step
# Epoch 427/500
# 43/43 - 0s - loss: 1.0831 - 59ms/epoch - 1ms/step
# Epoch 428/500
# 43/43 - 0s - loss: 1.0831 - 67ms/epoch - 2ms/step
# Epoch 429/500
# 43/43 - 0s - loss: 1.0830 - 63ms/epoch - 1ms/step
# Epoch 430/500
# 43/43 - 0s - loss: 1.0830 - 82ms/epoch - 2ms/step
# Epoch 431/500
# 43/43 - 0s - loss: 1.0829 - 75ms/epoch - 2ms/step
# Epoch 432/500
# 43/43 - 0s - loss: 1.0829 - 68ms/epoch - 2ms/step
# Epoch 433/500
# 43/43 - 0s - loss: 1.0828 - 61ms/epoch - 1ms/step
# Epoch 434/500
# 43/43 - 0s - loss: 1.0827 - 61ms/epoch - 1ms/step
# Epoch 435/500
# 43/43 - 0s - loss: 1.0827 - 65ms/epoch - 2ms/step
# Epoch 436/500
# 43/43 - 0s - loss: 1.0826 - 62ms/epoch - 1ms/step
# Epoch 437/500
# 43/43 - 0s - loss: 1.0826 - 68ms/epoch - 2ms/step
# Epoch 438/500
# 43/43 - 0s - loss: 1.0826 - 68ms/epoch - 2ms/step
# Epoch 439/500
# 43/43 - 0s - loss: 1.0825 - 60ms/epoch - 1ms/step
# Epoch 440/500
# 43/43 - 0s - loss: 1.0824 - 64ms/epoch - 1ms/step
# Epoch 441/500
# 43/43 - 0s - loss: 1.0823 - 62ms/epoch - 1ms/step
# Epoch 442/500
# 43/43 - 0s - loss: 1.0823 - 60ms/epoch - 1ms/step
# Epoch 443/500
# 43/43 - 0s - loss: 1.0823 - 58ms/epoch - 1ms/step
# Epoch 444/500
# 43/43 - 0s - loss: 1.0823 - 59ms/epoch - 1ms/step
# Epoch 445/500
# 43/43 - 0s - loss: 1.0822 - 66ms/epoch - 2ms/step
# Epoch 446/500
# 43/43 - 0s - loss: 1.0822 - 76ms/epoch - 2ms/step
# Epoch 447/500
# 43/43 - 0s - loss: 1.0821 - 82ms/epoch - 2ms/step
# Epoch 448/500
# 43/43 - 0s - loss: 1.0820 - 65ms/epoch - 2ms/step
# Epoch 449/500
# 43/43 - 0s - loss: 1.0820 - 59ms/epoch - 1ms/step
# Epoch 450/500
# 43/43 - 0s - loss: 1.0820 - 70ms/epoch - 2ms/step
# Epoch 451/500
# 43/43 - 0s - loss: 1.0819 - 60ms/epoch - 1ms/step
# Epoch 452/500
# 43/43 - 0s - loss: 1.0819 - 66ms/epoch - 2ms/step
# Epoch 453/500
# 43/43 - 0s - loss: 1.0818 - 67ms/epoch - 2ms/step
# Epoch 454/500
# 43/43 - 0s - loss: 1.0818 - 64ms/epoch - 1ms/step
# Epoch 455/500
# 43/43 - 0s - loss: 1.0817 - 58ms/epoch - 1ms/step
# Epoch 456/500
# 43/43 - 0s - loss: 1.0816 - 64ms/epoch - 1ms/step
# Epoch 457/500
# 43/43 - 0s - loss: 1.0816 - 60ms/epoch - 1ms/step
# Epoch 458/500
# 43/43 - 0s - loss: 1.0815 - 65ms/epoch - 2ms/step
# Epoch 459/500
# 43/43 - 0s - loss: 1.0815 - 63ms/epoch - 1ms/step
# Epoch 460/500
# 43/43 - 0s - loss: 1.0815 - 66ms/epoch - 2ms/step
# Epoch 461/500
# 43/43 - 0s - loss: 1.0815 - 71ms/epoch - 2ms/step
# Epoch 462/500
# 43/43 - 0s - loss: 1.0814 - 73ms/epoch - 2ms/step
# Epoch 463/500
# 43/43 - 0s - loss: 1.0813 - 69ms/epoch - 2ms/step
# Epoch 464/500
# 43/43 - 0s - loss: 1.0813 - 61ms/epoch - 1ms/step
# Epoch 465/500
# 43/43 - 0s - loss: 1.0812 - 65ms/epoch - 2ms/step
# Epoch 466/500
# 43/43 - 0s - loss: 1.0812 - 64ms/epoch - 1ms/step
# Epoch 467/500
# 43/43 - 0s - loss: 1.0811 - 59ms/epoch - 1ms/step
# Epoch 468/500
# 43/43 - 0s - loss: 1.0811 - 75ms/epoch - 2ms/step
# Epoch 469/500
# 43/43 - 0s - loss: 1.0811 - 70ms/epoch - 2ms/step
# Epoch 470/500
# 43/43 - 0s - loss: 1.0810 - 64ms/epoch - 1ms/step
# Epoch 471/500
# 43/43 - 0s - loss: 1.0810 - 73ms/epoch - 2ms/step
# Epoch 472/500
# 43/43 - 0s - loss: 1.0808 - 69ms/epoch - 2ms/step
# Epoch 473/500
# 43/43 - 0s - loss: 1.0808 - 70ms/epoch - 2ms/step
# Epoch 474/500
# 43/43 - 0s - loss: 1.0808 - 71ms/epoch - 2ms/step
# Epoch 475/500
# 43/43 - 0s - loss: 1.0807 - 68ms/epoch - 2ms/step
# Epoch 476/500
# 43/43 - 0s - loss: 1.0807 - 70ms/epoch - 2ms/step
# Epoch 477/500
# 43/43 - 0s - loss: 1.0807 - 66ms/epoch - 2ms/step
# Epoch 478/500
# 43/43 - 0s - loss: 1.0807 - 79ms/epoch - 2ms/step
# Epoch 479/500
# 43/43 - 0s - loss: 1.0806 - 61ms/epoch - 1ms/step
# Epoch 480/500
# 43/43 - 0s - loss: 1.0805 - 67ms/epoch - 2ms/step
# Epoch 481/500
# 43/43 - 0s - loss: 1.0805 - 65ms/epoch - 2ms/step
# Epoch 482/500
# 43/43 - 0s - loss: 1.0805 - 59ms/epoch - 1ms/step
# Epoch 483/500
# 43/43 - 0s - loss: 1.0804 - 67ms/epoch - 2ms/step
# Epoch 484/500
# 43/43 - 0s - loss: 1.0804 - 67ms/epoch - 2ms/step
# Epoch 485/500
# 43/43 - 0s - loss: 1.0803 - 61ms/epoch - 1ms/step
# Epoch 486/500
# 43/43 - 0s - loss: 1.0802 - 64ms/epoch - 1ms/step
# Epoch 487/500
# 43/43 - 0s - loss: 1.0802 - 65ms/epoch - 2ms/step
# Epoch 488/500
# 43/43 - 0s - loss: 1.0802 - 61ms/epoch - 1ms/step
# Epoch 489/500
# 43/43 - 0s - loss: 1.0801 - 63ms/epoch - 1ms/step
# Epoch 490/500
# 43/43 - 0s - loss: 1.0801 - 72ms/epoch - 2ms/step
# Epoch 491/500
# 43/43 - 0s - loss: 1.0800 - 82ms/epoch - 2ms/step
# Epoch 492/500
# 43/43 - 0s - loss: 1.0800 - 94ms/epoch - 2ms/step
# Epoch 493/500
# 43/43 - 0s - loss: 1.0799 - 92ms/epoch - 2ms/step
# Epoch 494/500
# 43/43 - 0s - loss: 1.0799 - 79ms/epoch - 2ms/step
# Epoch 495/500
# 43/43 - 0s - loss: 1.0798 - 81ms/epoch - 2ms/step
# Epoch 496/500
# 43/43 - 0s - loss: 1.0798 - 84ms/epoch - 2ms/step
# Epoch 497/500
# 43/43 - 0s - loss: 1.0798 - 78ms/epoch - 2ms/step
# Epoch 498/500
# 43/43 - 0s - loss: 1.0798 - 95ms/epoch - 2ms/step
# Epoch 499/500
# 43/43 - 0s - loss: 1.0797 - 83ms/epoch - 2ms/step
# Epoch 500/500
# 43/43 - 0s - loss: 1.0796 - 64ms/epoch - 1ms/step

# %% [markdown]
# # Prediction

# %%
predict = model.predict(test_X)
predict = [float(predict[i]) for i in range(len(predict))]
predict[:10]
# Out:
# [0.058903127908706665,
#  0.5092862248420715,
#  0.34884336590766907,
#  0.26572465896606445,
#  0.27556896209716797,
#  0.21704255044460297,
#  0.2741868495941162,
#  0.41775959730148315,
#  0.43708541989326477,
#  0.5056423544883728]

# %%
def ud_pred(pred, actual):
    up_down = [1]
    for i in range(1,len(pred)):
        if pred[i] > actual[i-1]:
            up_down.append(1)
        else:
            up_down.append(0)
    return up_down

def ud(predict):
    up_down = [1]
    for i in range(1,len(predict)):
        if predict[i] > predict[i-1]:
            up_down.append(1)
        else:
            up_down.append(0)
    return up_down

# %%
# Scale back predictions
def scale_back(pred, close):
    predict = [close[0]]
    for i in range(1,len(pred)):
        predict.append(pred[i]+list(close)[i-1])
    return predict

# %%
pred = scale_back(predict, close_test)

# %%
updown_pred = ud_pred(pred, close_test)

# %%
close_test[-2], pred[-1]
# Out:
# (133.52000427246094, 137.21101349592206)

# %%
df = pd.DataFrame(updown_pred)
df["Close"] = close_test[:-1]
df["updown_pred"] = df.iloc[:,0]
df["updown_actual"] = ud(close_test[:-1])
df["Scaled_pred"] = pred
df["Pred"] = predict
df = df.iloc[:,1:] 
print('Model Accuracy: ', (df["updown_pred"] == df["updown_actual"]).sum()/df.shape[0])
print('Baseline Accuracy: 0.5')
df.head()
# Out:
# Model Accuracy:  0.6219512195121951
# Baseline Accuracy: 0.5
#         Close  updown_pred  updown_actual  Scaled_pred      Pred
# 0  142.562134            1              1   142.562134  0.058903
# 1  142.418732            1              0   143.071420  0.509286
# 2  143.891006            1              1   142.767575  0.348843
# 3  145.267685            1              1   144.156731  0.265725
# 4  145.095596            1              0   145.543254  0.275569

# %%
plt.plot(df['Scaled_pred'], label='pred')
plt.plot(df["Close"], label='Close')
plt.legend()
plt.show()

# %%
commission = 0.00
def long_equity(prediction, close):
    long = [close[0]]
    for i in range(1,len(prediction)-1):
        if prediction[i] > close[i-1]:
            long.append(close[i] - close[i-1] - close[i-1]*commission)
        else:
            long.append(0)
    return long

def short_equity(prediction, close):
    short = [close[0]]
    for i in range(1,len(prediction)-1):
        if prediction[i] < close[i-1]:
            short.append(close[i-1] - close[i] - close[i-1]*commission)
        else:
            short.append(0)
    return short  

def total_equity(prediction, close):
    total = [close[0]]
    for i in range(1,len(prediction)-1):
        if prediction[i] > close[i-1]:
            total.append(close[i] - close[i-1] - close[i-1]*commission)
        else:
            total.append(close[i-1] - close[i] - close[i-1]*commission)
    return total

# def percentage_returns(equity):
#     equity = 0
#     for i in range(1,len(equity))

# %%
df_equity = pd.DataFrame()
df_equity["long_equity"] = long_equity(df["Scaled_pred"], df["Close"])
df_equity["short_equity"] = short_equity(df["Scaled_pred"], df["Close"])
df_equity["total_equity"] = total_equity(df["Scaled_pred"], df["Close"])
df_equity["short_equity"].cumsum().plot()
df_equity["long_equity"].cumsum().plot()
df_equity["total_equity"].cumsum().plot()
df["Close"].plot()
# df["Pred"].shift(-1).plot()
plt.legend()
